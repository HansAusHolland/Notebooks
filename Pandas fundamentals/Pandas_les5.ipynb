# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style 
import numpy as np

# %%
df = pd.read_html("https://nl.wikipedia.org/wiki/Bevolking_van_Nederland", match="Verdeling levensbeschouwelijke groeperingen in 2022")

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#                     Religie Percentage
# 0  Geen kerkelijke gezindte      57,2%
# 1           Rooms-katholiek      18,2%
# 2               Protestants      13,2%
# 3                     Islam       5,6%
# 4           Ander gezindten       5,9%

# %%
percentage = df[0]["Percentage"].str.replace(",",".").str.rstrip("%")
percentage = pd.to_numeric(percentage)

# %%
percentage
# Out:
# 0    57.2
# 1    18.2
# 2    13.2
# 3     5.6
# 4     5.9
# Name: Percentage, dtype: float64

# %%
gezindte = pd.DataFrame({"Religie":religie,
                   "Percentage":percentage})

# %%
gezindte
# Out:
#                     Religie  Percentage
# 0  Geen kerkelijke gezindte        57.2
# 1           Rooms-katholiek        18.2
# 2               Protestants        13.2
# 3                     Islam         5.6
# 4           Ander gezindten         5.9

# %%
gezindte["Percentage"].sum().round(1)
# Out:
# 100.1

# %%
plt.bar(gezindte["Religie"], gezindte["Percentage"].values, color=("tab:orange"), edgecolor="black")
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_linewidth(10)
plt.gca().spines['left'].set_linewidth(2)
plt.ylabel("Percentage in %", fontsize=14, labelpad=30)
plt.xlabel("Gezindte", fontsize=14)
plt.xticks(rotation=45,ha="right", fontsize=10)
plt.grid(axis="y")
