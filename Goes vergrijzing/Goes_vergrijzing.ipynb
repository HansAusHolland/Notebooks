# %%
import pandas as pd
import matplotlib.pyplot as plt

data_pad = "/Users/hbraakmann/Desktop/oudelande.csv"

df_oudelande = pd.read_csv(data_pad)
oudelande = df_oudelande.iloc[0:, 2:].T

# %%
groep = ["0-15 jaar", "15-25 jaar", "25-45 jaar", "45-65 jaar", "> 65 jaar"]
aantal_oudelande = oudelande.values.flatten().astype(int)

#labels = [f"{g}\n{a}%" for g, a in zip(groep,aantal)]
explode = [0, 0, 0, 0.08, 0.05]

# %%
plt.figure(figsize=(6, 6))
plt.pie(aantal_oudelande,labels=labels,labeldistance=0.7,startangle=90,explode=explode,
        textprops={"color":"white","ha":"center","va":"center","fontweight":"bold"})
plt.title("Oudelande bevolkingsopbouw", fontweight="bold")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6), facecolor="black")

ax.pie(aantal_oudelande,labels=labels,
       labeldistance=0.7,
       startangle=90,
       explode=explode,
       wedgeprops={"edgecolor":"white", "linewidth": 2},
       textprops={"color":"white","ha":"center","va":"center","fontweight":"bold"})

ax.set_title("Oudelande bevolkingsopbouw", color="white", fontweight="bold", fontsize=14)
fig.text(0.5, 0.92, "Inwoneraantal 2024: 600 inw.", ha="center", color="grey", fontstyle="italic", fontweight="bold")
plt.tight_layout()
plt.show()

# %%
labels
# Out:
# ['0-15 jaar\n12%',
#  '15-25 jaar\n11%',
#  '25-45 jaar\n17%',
#  '45-65 jaar\n36%',
#  '> 65 jaar\n22%']

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_pad = "/Users/hbraakmann/Desktop/goes_inwoners.csv"

df_goes = pd.read_csv(data_pad)
goes = df_goes.iloc[0:, 2:-1]

groep = ["0-15 jaar", "15-25 jaar", "25-45 jaar", "45-65 jaar", "> 65 jaar"]
aantal_goes = goes.values.flatten()

labels = [f"{g}\n{a}%" for g, a in zip(groep, aantal)]
explode = [0, 0, 0, 0.08, 0.05]

# %%
fig, ax = plt.subplots(figsize=(6, 6), facecolor="black")

ax.pie(aantal_goes, labels=labels,
       labeldistance=0.7,
       startangle=90,
       explode = explode,
       wedgeprops={"edgecolor":"white", "linewidth":2},
       textprops={"color":"white", "ha":"center", "va":"center", "fontweight":"bold"})

ax.set_title("Goes bevolkingsopbouw", color="white", fontweight="bold", fontsize=14)
fig.text(0.5, 0.92, "Inwoneraantal 2024: 29590 inw.", ha="center", color="grey", fontstyle="italic", fontweight="bold")
plt.tight_layout()
plt.show()

# %%
df_goes
# Out:
#    aantal_inwoners gemeentenaam  percentage_personen_0_tot_15_jaar  \
# 0            29590         Goes                                 14
#
#    percentage_personen_15_tot_25_jaar  percentage_personen_25_tot_45_jaar  \
# 0                                  11                                  23
#
#    percentage_personen_45_tot_65_jaar  percentage_personen_65_jaar_en_ouder  \
# 0                                  27                                    25
#
#        wijknaam
# 0  Wijk 01 Goes
